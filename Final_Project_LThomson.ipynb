# %% [markdown]
# # DATA 602 - FINAL PROJECT
# ## CRAFT BREWERY GROWTH & STATE EMPLOYMENT

# %% [markdown]
# ### IMPORT MODULES & PACKAGES
#
# This project was used as an opportunity to hone a few Python skills that I wanted to sharpen - mainly web scraping and working with regular expressions, opening files from Excel, and using a different visualization package (`Bokeh`).

# %%
from bs4 import BeautifulSoup
import urllib2
import json
import requests
import re
import pandas as pd
import openpyxl
from bokeh.charts import Bar, Scatter, output_file, show
from bokeh.layouts import row, gridplot
from bokeh.io import output_notebook

pd.options.display.max_columns = 35

# %% [markdown]
# ### SCRAPE BEER DATA

# %% [markdown]
# Most of the data that I wanted to use is located on the National Brewers Association website. One of the reasons I chose this data source was the line charts for each state - they are javascript, and I wanted to see if I could pull the information out, in addition to the information stored in more conventional html format.

# %%
webpage = ('https://www.brewersassociation.org/statistics/by-state/')
html = urllib2.urlopen(webpage).read()

# %%
soup = BeautifulSoup(html, 'lxml')

# %% [markdown]
# Here we're just grabbing the names of the states, basically a BeautifulSoup practice run. After that, the rest of the data is stored in the `span` tag, which is simply accessed from simple list indexing.

# %%
state_html = soup.find_all('h1')
state_html = state_html[2:]
state_html[0:5]

states = []
for st in state_html:
    states.append(str(st.get_text()))

states[0:5]
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California']

# %%
stats = soup.find_all('span', {'class':'count'}, text=True)

craft_breweries = stats[::6]
per_capita = stats[1::6]
econ_impact = stats[2::6]
impact_capita = stats[3::6]
barrels = stats[4::6]
gallons_per = stats[5::6]

# %% [markdown]
# #### GET TEXT, CONVERT TO NUMERICAL FORMAT
#
# Since all of the numerical data is stored as text, and there were multiple lists of values, I created a quick function to do the repetitive work of getting the text, replacing the commas, then converting the text to a float value. The results were then stored in an object of the same name (i.e. `barrels = get_text(barrels`).

# %%
# create lists, append each line to list, create dataframe
def get_text(tag_list):
    """Converts html text to string, removes any commas, and coverts to float.
    Args:
        tag_list(list): A list of html tags
    
    Returns:
        temp(list): A list of float values from converted html text.    
    """
    temp = []
    for item in tag_list:
        temp_str = item.get_text()
        temp_str = temp_str.replace(',', '')
        temp.append(float(temp_str))
    return temp

# %%
craft_breweries = get_text(craft_breweries)
per_capita = get_text(per_capita)
econ_impact = get_text(econ_impact)
impact_capita = get_text(impact_capita)
barrels = get_text(barrels)
gallons_per = get_text(gallons_per)

# %%
# First five records, and length of list for demonstration purposes

gallons_per[:5], len(gallons_per)
# Out:
# ([0.4, 12.7, 1.2, 0.4, 4.3], 51)

# %% [markdown]
# ### Getting Javascript Values

# %% [markdown]
# There's probably a more pythonic way to do this, but I was happy with the results. Gathering the number of breweries per year for each state was a little more complicated.
#
# BeautifulSoup was used to access the javascript, which was then converted to a string, split up on the `<script>` tag, and then a "for-loop" with the help of some regular expressions filtered out the rest.

# %%
state_stats = soup.find('section', {'id': 'primary'})
script = state_stats.findAll('script')

script = str(script)

script = script.split('<script>')
values = script[2]

brew_per_yr = []
for i in range(1, len(script)):
    date = re.findall(r'"value": "\d{1,3}"', script[i])
    for j in date:
        #print j[9:14]
        hi = re.search(r'\d{1,3}', j)
        brew_per_yr.append(hi.group())
        
brew_per_yr[0:10]
# Out:
# ['6', '10', '13', '19', '24', '20', '22', '22', '22', '27']

# %% [markdown]
# Similar to the other data above, list indices were used to access the information stored in a list in the appropriate year.

# %%
brew_2011 = brew_per_yr[::5]
brew_2012 = brew_per_yr[1::5]
brew_2013 = brew_per_yr[2::5]
brew_2014 = brew_per_yr[3::5]
brew_2015 = brew_per_yr[4::5]
brew_2015[0:5]
# Out:
# ['24', '27', '78', '26', '518']

# %% [markdown]
# ### Create Beer Dataframe

# %% [markdown]
# Each list of the data was combined using the `zip` function, columns re-named, and then the values of the `State` column were renamed for later merging with the other DataFrames that will be created. It was easier to change all of the full state names to abbreviations for one data set, rather than the other way around for two others.

# %%
beer_table = zip(states, craft_breweries, per_capita, econ_impact, impact_capita, barrels, 
                 gallons_per, brew_2011, brew_2012, brew_2013, brew_2014, brew_2015)

beer_df = pd.DataFrame(beer_table, columns = ['State', 'Craft_Breweries', 'Breweries Per Capita', 'Econ. Impact', 
                                              'Econ.Impact/Capita', 'Barrels', 'Gallons/Adult', 
                                              '2011', '2012', '2013', '2014', '2015'])

beer_df['State'] = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL',  # use state abbrevs for later join
 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 
 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 
 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 
 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

beer_df.head()
# Out:
#   State  Craft_Breweries  Breweries Per Capita  Econ. Impact  \
# 0    AL             24.0                   0.7         438.0
# 1    AK             27.0                   5.3         239.0
# 2    AZ             78.0                   1.6         960.0
# 3    AR             26.0                   1.2         324.0
# 4    CA            518.0                   1.9        6887.0
#
#    Econ.Impact/Capita    Barrels  Gallons/Adult 2011 2012 2013 2014 2015
# 0              125.53    50369.0            0.4    6   10   13   19   24
# 1              469.09   209644.0           12.7   20   22   22   22   27
# 2              203.25   187213.0            1.2   34   45   47   53   78
# 3              153.03    24623.0            0.4    6   10   13   19   26
# 4              251.89  3799785.0            4.3  270  319  381  431  518

# %% [markdown]
# ### Downloaded Beer Data from TTB

# %% [markdown]
# This next set of data was obtained from the TTB website (www.ttb.gov), the Alcohol and Tobacco Tax and Trade Bureau. They do not supply a nice API or even .csv files, just Excel file formats or .pdf files containing state-by-state beer production stats.
#
# Since most of the data I have worked with in Python is conveniently in .csv files, I took the opportunity to learn a bit about using `openpyxl` to access some of this data. Unfortunately, storing the information on GitHub and pulling it directly from there wasn't an option, so you will need to download and store the files in the same directory as this notebook file.

# %%
wb = openpyxl.load_workbook('aggr-data-beer-2010-2015.xlsx')
# Out:
# /Users/Logan/anaconda/lib/python2.7/site-packages/openpyxl/workbook/names/named_range.py:124: UserWarning: Discarded range with reserved name
#   warnings.warn("Discarded range with reserved name")

# %% [markdown]
# It's a fairly simple method to access the information. `openpyxl` can access sheets by name, and columns/rows as well - sort of like "slicing" a big Python list.
#
# The individual sheets were stored in objects, and then nested for-loops were used to get the information from each column and store it in a list object.

# %%
wb.get_sheet_names()
# Out:
# [u'Tax Determined (Premise Use)', u'Bottles and Cans', u'Barrels and Kegs']

# %%
bottle_can = wb.get_sheet_by_name('Bottles and Cans')
barrel_keg = wb.get_sheet_by_name('Barrels and Kegs')

bc_list = []
bk_list = []

for i in range(len(bottle_can.columns)):
    cols = []
    b = bottle_can.columns[i]
    for bc in b:
        cols.append(bc.value)
    bc_list.append(cols)

for i in range(len(barrel_keg.columns)):
    cols = []
    b = barrel_keg.columns[i]
    for bk in b:
        cols.append(bk.value)
    bk_list.append(cols)

bc_list[1][2], bk_list[1][2]
# Out:
# (80889.21, 54395.32)

# %% [markdown]
# #### CREATE TTB DATAFRAME
#
# Same was used to put together all of the individual lists from the Bottles & Cans sheet, and the Barrels & Kegs sheet, then columns were re-named, then empty and formula rows were dropped from the DataFrame.
#
# The two pandas DataFrames were then merged on the `State` column, and the columns were re-ordered by name. A preview of the findal combined DataFrame is below.

# %%
# Beer Production by State - Bottle & Cans (in Barrels)
tbb_bc = pd.DataFrame(zip(bc_list[0], bc_list[1], bc_list[2], bc_list[3], bc_list[4], bc_list[5], bc_list[6]))

tbb_bc.columns =  (['State', 'Btls & Cans (in Barrels) 2010', 'Btls & Cans (in Barrels) 2011', 
                    'Btls & Cans (in Barrels) 2012', 'Btls & Cans (in Barrels) 2013', 'Btls & Cans (in Barrels) 2014', 
                    'Btls & Cans (in Barrels) 2015'])

tbb_bc = tbb_bc.reindex(tbb_bc.index.drop([0, 1, 53, 54]))

# %%
# Beer Production by State - Barrels & Kegs (in Barrels)
tbb_bk = pd.DataFrame(zip(bk_list[0], bk_list[1], bk_list[2], bk_list[3], bk_list[4], bk_list[5], bk_list[6]))

tbb_bk.columns =  (['State', 'Barrels & Kegs (in Barrels) 2010', 'Barrels & Kegs (in Barrels) 2011', 
                    'Barrels & Kegs (in Barrels) 2012', 'Barrels & Kegs (in Barrels) 2013', 
                    'Barrels & Kegs (in Barrels) 2014', 'Barrels & Kegs (in Barrels) 2015'])

tbb_bk = tbb_bk.reindex(tbb_bk.index.drop([0, 1, 53, 54]))

# %%
tbb = pd.merge(tbb_bc, tbb_bk, on='State')

tbb = tbb[['State', 'Barrels & Kegs (in Barrels) 2010', 'Btls & Cans (in Barrels) 2010', 
           'Barrels & Kegs (in Barrels) 2011', 'Btls & Cans (in Barrels) 2011', 
           'Barrels & Kegs (in Barrels) 2012', 'Btls & Cans (in Barrels) 2012', 
           'Barrels & Kegs (in Barrels) 2013', 'Btls & Cans (in Barrels) 2013', 
           'Barrels & Kegs (in Barrels) 2014', 'Btls & Cans (in Barrels) 2014', 
           'Barrels & Kegs (in Barrels) 2015', 'Btls & Cans (in Barrels) 2015',]]

tbb.head()
# Out:
#   State Barrels & Kegs (in Barrels) 2010 Btls & Cans (in Barrels) 2010  \
# 0    AK                          54395.3                       80889.2
# 1    AL                           547.69                             0
# 2    AR                          1318.17                       1445.82
# 3    AZ                          24410.5                       10380.3
# 4    CA                      2.19855e+06                   1.90956e+07
#
#   Barrels & Kegs (in Barrels) 2011 Btls & Cans (in Barrels) 2011  \
# 0                          58519.7                       94781.6
# 1                          1810.06                        658.96
# 2                          1144.17                       1382.06
# 3                          32848.9                       14057.6
# 4                      2.16603e+06                   1.82045e+07
#
#   Barrels & Kegs (in Barrels) 2012 Btls & Cans (in Barrels) 2012  \
# 0                          65679.1                        105416
# 1                          6453.45                       2485.79
# 2                           125.94                             8
# 3                          44792.7                       18411.2
# 4                      2.27266e+06                   1.89403e+07
#
#   Barrels & Kegs (in Barrels) 2013 Btls & Cans (in Barrels) 2013  \
# 0                          68867.6                        112009
# 1                          11747.7                       6634.43
# 2                          1078.21                             8
# 3                            59074                       22318.7
# 4                      2.38332e+06                   1.78355e+07
#
#   Barrels & Kegs (in Barrels) 2014 Btls & Cans (in Barrels) 2014  \
# 0                          73823.6                        129182
# 1                            13750                       9521.26
# 2                          2787.48                        800.09
# 3                          80134.1                         29645
# 4                      2.32851e+06                   1.80529e+07
#
#   Barrels & Kegs (in Barrels) 2015 Btls & Cans (in Barrels) 2015
# 0                          74606.3                        126309
# 1                          11465.2                         10543
# 2                          6965.83                        872.11
# 3                          74997.9                       44081.1
# 4                      2.17332e+06                   1.76706e+07

# %% [markdown]
# ## BLS DATA

# %% [markdown]
# Originally, I intended to obtain this data using the public ("V1") API made available by the Bureau of Labor Statistics. However, there appears to be a problem with the API calls, this may have something to do with the BLS and Census website changing the URLs and locations of some of their data only days ago.
#
# Instead, I simply relied on BeautifulSoup to get the data I was looking for. State-by-state unemployment rate averages for the entire year are not easy to find on the BLS website. In the end, it was probably better to access this information this way, rather than using the API.

# %%
def get_bls(url):
    """Obtains unemployment rank, state name, and unemployment rate for a given URL
    on the bls.gov website.
    
    Args: 
        url(string): the website address for the table data given as a string.  
        
    Returns: 
        a list of lists containing the rank, state, and unemployment rate data.
    """
    webpage = (url)
    html = urllib2.urlopen(webpage).read()
    soup = BeautifulSoup(html, 'lxml')
    
    bls = soup.find_all('td', text=True)
    rank = bls[0::3]
    state = bls[1::3]
    rate = bls[2::3]
    
    ranks = []
    for i in rank:
        ranks.append((i.get_text()))
    
    states = []
    for i in state:
        states.append(i.get_text())
    
    rates = []
    for i in rate:
        rates.append(float(i.get_text()))
    
    return [ranks, states, rates]

# %% [markdown]
# A quick function to create individual DataFrames and rename the columns (to differentiate after combining the data) was created.

# %%
def df_bls(bls_list, rank_yr, rate_yr):
    """Takes lists created from BLS data, creates a DataFrame, and renames the columns.
    
    Args:
        bls_list(list): a list of lists generated by the get_bls function.
        rank_yr(string): a string to name the rank column and designate the year of the data.
        rate_yr(string): a string to name the rate column and designate the year of the data.
        
    Returns:
        bls_unemp(pandas DataFrame): A pandas DataFrame of the BLS data.    
    """
    bls_unemp = pd.DataFrame(zip(bls_list[0], bls_list[1], bls_list[2]), 
                             columns=['{}'.format(rank_yr), 'State', '{}'.format(rate_yr)])
    return bls_unemp

# %% [markdown]
# Lastly, each URL of the location for each year of unemployment data is passed to the `get_bls` function, then passed to the `df_bls` function and stored in an appropriately named Python object:

# %%
unemp_15 = get_bls('https://www.bls.gov/lau/lastrk15.htm')
unemp_15 = df_bls(unemp_15, '2015 Rank', '2015 Rate')

unemp_14 = get_bls('https://www.bls.gov/lau/lastrk14.htm')
unemp_14 = df_bls(unemp_14, '2014 Rank', '2014 Rate')

unemp_13 = get_bls('https://www.bls.gov/lau/lastrk13.htm')
unemp_13 = df_bls(unemp_13, '2013 Rank', '2013 Rate')

unemp_12 = get_bls('https://www.bls.gov/lau/lastrk12.htm')
unemp_12 = df_bls(unemp_12, '2012 Rank', '2012 Rate')

unemp_11 = get_bls('https://www.bls.gov/lau/lastrk11.htm')
unemp_11 = df_bls(unemp_11, '2011 Rank', '2011 Rate')

# %% [markdown]
# A "chained" merge is used to combine all of the individual unemployment data sets, the columns are re-ordered, and the state names are changed again to abbreviations.  A preview of the first five rows of the BLS unemployment data frame is below.

# %%
# df1.merge(df2,on='name').merge(df3,on='name')
state_unemp = unemp_15.merge(unemp_14, 
                             on='State').merge(unemp_13, 
                                               on='State').merge(unemp_12, 
                                                                 on='State').merge(unemp_11, 
                                                                                   on='State')

state_unemp = state_unemp[['State', '2011 Rank', '2011 Rate', '2012 Rank', '2012 Rate', 
                           '2013 Rank', '2013 Rate', '2014 Rank', '2014 Rate', 
                           '2015 Rank', '2015 Rate']]  # Reorder columns

state_unemp = state_unemp.drop(state_unemp.index[[0]])

#state_unemp = state_unemp.set_value(51, 'State', 'DC')

state_unemp['State'] = ['ND', 'NE', 'SD', 'NH', 'UT', 'HI', 'IA', 'MN', 'VT', 'CO',  # use state abbrevs for later join
 'ID', 'MT', 'KS', 'OK', 'WY', 'ME', 'VA', 'TX', 'WI', 'IN', 
 'DE', 'OH', 'MA', 'MO', 'PA', 'AR', 'MD', 'NY', 'FL', 'KY', 
 'MI', 'CT', 'NJ', 'NC', 'OR', 'WA', 'TN', 'GA', 'IL', 'RI', 
 'SC', 'AL', 'AZ', 'CA', 'LA', 'AK', 'MS', 'NM', 'NV', 'WV', 'DC']

state_unemp.head()
# Out:
#   State 2011 Rank  2011 Rate 2012 Rank  2012 Rate 2013 Rank  2013 Rate  \
# 1    ND         1        3.5         1        3.1         1        2.9
# 2    NE         2        4.4         2        4.0         2        3.8
# 3    SD         3        4.7         3        4.3         2        3.8
# 4    NH         4        5.4         9        5.5        10        5.1
# 5    UT        12        6.7         8        5.4         5        4.6
#
#   2014 Rank  2014 Rate 2015 Rank  2015 Rate
# 1         1        2.7         1        2.7
# 2         2        3.3         2        3.0
# 3         3        3.4         3        3.1
# 4         9        4.3         4        3.4
# 5         4        3.8         5        3.5

# %% [markdown]
# ### CREATE MASTER DATAFRAME

# %% [markdown]
# The three data frames (`beer_df`, `tbb`, and `state_unemp`) are the merged together. Also, the data in many of the columns was captured as a pandas "object" (text), and needed to be converted into a float value in order to do any calculations.
#
# A preview of the final DataFrame is below.

# %%
master_df = beer_df.merge(tbb, on='State').merge(state_unemp, on='State')

for col in ['2011', '2012', '2013', '2014', '2015', 'Barrels & Kegs (in Barrels) 2010',  
            'Btls & Cans (in Barrels) 2010', 'Barrels & Kegs (in Barrels) 2011', 
            'Btls & Cans (in Barrels) 2011', 'Barrels & Kegs (in Barrels) 2012', 
            'Btls & Cans (in Barrels) 2012', 'Barrels & Kegs (in Barrels) 2013', 
            'Btls & Cans (in Barrels) 2013', 'Barrels & Kegs (in Barrels) 2014', 
            'Btls & Cans (in Barrels) 2014', 'Barrels & Kegs (in Barrels) 2015', 
            'Btls & Cans (in Barrels) 2015', '2011 Rank', '2012 Rank', '2013 Rank', 
            '2014 Rank', '2015 Rank']:
    master_df[col] = master_df[col].astype('float64')  # need to convert column types from object to float64

master_df
# Out:
#    State  Craft_Breweries  Breweries Per Capita  Econ. Impact  \
# 0     AL             24.0                   0.7         438.0
# 1     AK             27.0                   5.3         239.0
# 2     AZ             78.0                   1.6         960.0
# 3     AR             26.0                   1.2         324.0
# 4     CA            518.0                   1.9        6887.0
# 5     CO            284.0                   7.3        2716.0
# 6     CT             35.0                   1.3         569.0
# 7     DE             15.0                   1.9         264.0
# 8     DC             10.0                   2.2         149.0
# 9     FL            151.0                   1.0        2056.0
# 10    GA             45.0                   0.6        1135.0
# 11    HI             13.0                   1.2         232.0
# 12    ID             50.0                   4.4         318.0
# 13    IL            157.0                   1.7        2272.0
# 14    IN            115.0                   2.5        1076.0
# 15    IA             58.0                   2.6         636.0
# 16    KS             26.0                   1.3         383.0
# 17    KY             24.0                   0.8         495.0
# 18    LA             20.0                   0.6         646.0
# 19    ME             59.0                   5.9         432.0
# 20    MD             60.0                   1.4         652.0
# 21    MA             84.0                   1.7        1408.0
# 22    MI            205.0                   2.9        1852.0
# 23    MN            105.0                   2.7        1324.0
# 24    MS              8.0                   0.4         223.0
# 25    MO             71.0                   1.7         921.0
# 26    MT             49.0                   6.5         328.0
# 27    NE             33.0                   2.5         424.0
# 28    NV             34.0                   1.7         480.0
# 29    NH             44.0                   4.5         359.0
# 30    NJ             51.0                   0.8        1236.0
# 31    NM             45.0                   3.1         340.0
# 32    NY            208.0                   1.4        2921.0
# 33    NC            161.0                   2.2        1200.0
# 34    ND              9.0                   1.6         174.0
# 35    OH            143.0                   1.7        2162.0
# 36    OK             14.0                   0.5         416.0
# 37    OR            228.0                   7.7        1837.0
# 38    PA            178.0                   1.9        4488.0
# 39    RI             14.0                   1.8         160.0
# 40    SC             36.0                   1.0         443.0
# 41    SD             14.0                   2.3         157.0
# 42    TN             52.0                   1.1         753.0
# 43    TX            189.0                   1.0        3770.0
# 44    UT             22.0                   1.2         390.0
# 45    VT             44.0                   9.4         271.0
# 46    VA            124.0                   2.0        1046.0
# 47    WA            305.0                   5.9        1654.0
# 48    WV             12.0                   0.9         211.0
# 49    WI            121.0                   2.9        1748.0
# 50    WY             23.0                   5.5         150.0
#
#     Econ.Impact/Capita    Barrels  Gallons/Adult   2011   2012   2013   2014  \
# 0               125.53    50369.0            0.4    6.0   10.0   13.0   19.0
# 1               469.09   209644.0           12.7   20.0   22.0   22.0   22.0
# 2               203.25   187213.0            1.2   34.0   45.0   47.0   53.0
# 3               153.03    24623.0            0.4    6.0   10.0   13.0   19.0
# 4               251.89  3799785.0            4.3  270.0  319.0  381.0  431.0
# 5               709.39  1775831.0           14.1  126.0  151.0  175.0  235.0
# 6               216.34   105484.0            1.2   16.0   21.0   23.0   27.0
# 7               389.08   248742.0           11.2    7.0    9.0   10.0   11.0
# 8               293.10    29727.0            1.8    6.0    6.0    9.0    8.0
# 9               138.40  1207936.0            2.5   45.0   57.0   66.0  111.0
# 10              160.78   365015.0            1.6   21.0   22.0   28.0   40.0
# 11              221.22    40853.0            1.2    7.0    9.0    8.0   10.0
# 12              284.73    67597.0            1.9   24.0   31.0   34.0   43.0
# 13              247.08   595237.0            2.0   54.0   68.0   83.0  103.0
# 14              230.56   182978.0            1.2   46.0   55.0   63.0   80.0
# 15              285.64    54472.0            0.8   27.0   34.0   40.0   46.0
# 16              188.14    46288.0            0.7   17.0   19.0   20.0   22.0
# 17              155.27    87156.0            0.8   11.0   14.0   15.0   18.0
# 18              195.98   202764.0            1.9    8.0    8.0   11.0   15.0
# 19              430.85   287257.0            8.9   34.0   37.0   47.0   52.0
# 20              150.66   258926.0            1.8   25.0   31.0   34.0   40.0
# 21              282.77   446158.0            2.8   45.0   49.0   57.0   61.0
# 22              260.03   769897.0            3.3  105.0  122.0  131.0  159.0
# 23              337.59   631955.0            5.0   35.0   47.0   52.0   73.0
# 24              103.74    30790.0            0.4    2.0    3.0    4.0    7.0
# 25              217.15   359864.0            2.6   43.0   45.0   49.0   55.0
# 26              437.64   171276.0            7.0   33.0   36.0   39.0   44.0
# 27              319.80    39505.0            0.9   18.0   19.0   22.0   32.0
# 28              236.79    64901.0            1.0   18.0   22.0   22.0   25.0
# 29              365.72    94094.0            3.0   15.0   19.0   22.0   26.0
# 30              190.19    79942.0            0.4   24.0   25.0   26.0   32.0
# 31              231.60    85230.0            1.8   25.0   28.0   31.0   36.0
# 32              201.88  1086718.0            2.3   75.0   92.0  165.0  181.0
# 33              168.16   675469.0            2.9   59.0   71.0   91.0  101.0
# 34              322.90     8452.0            0.5    2.0    4.0    6.0    6.0
# 35              258.66  1385100.0            5.1   45.0   58.0   76.0  110.0
# 36              151.43    34381.0            0.4   10.0   10.0   13.0   10.0
# 37              631.35  1081152.0           11.3  124.0  145.0  181.0  216.0
# 38              476.98  4059330.0           13.4   88.0  104.0  108.0  136.0
# 39              206.39    20807.0            0.8    6.0    8.0    8.0   11.0
# 40              127.23    80155.0            0.7   16.0   16.0   20.0   31.0
# 41              259.87     8547.0            0.4    5.0    7.0   10.0   12.0
# 42              159.20   142818.0            0.9   24.0   30.0   35.0   39.0
# 43              204.94  1135043.0            1.9   59.0   84.0   96.0  117.0
# 44              208.52   183660.0            3.0   16.0   16.0   16.0   20.0
# 45              579.52   261654.0           17.4   22.0   27.0   29.0   40.0
# 46              173.18   274111.0            1.4   40.0   50.0   61.0   78.0
# 47              323.92   426462.0            2.5  136.0  170.0  201.0  256.0
# 48              152.16    14161.0            0.3    5.0    6.0    7.0   11.0
# 49              420.20  1020567.0            7.6   73.0   84.0   90.0   97.0
# 50              356.88    21053.0            1.6   13.0   15.0   18.0   22.0
#
#      2015  Barrels & Kegs (in Barrels) 2010  Btls & Cans (in Barrels) 2010  \
# 0    24.0                            547.69                           0.00
# 1    27.0                          54395.32                       80889.21
# 2    78.0                          24410.52                       10380.26
# 3    26.0                           1318.17                        1445.82
# 4   518.0                        2198550.10                    19095643.27
# 5   284.0                        2279812.02                    18742266.67
# 6    35.0                           6823.23                        4822.66
# 7    15.0                          48117.54                       89753.27
# 8    10.0                              0.00                         184.80
# 9   151.0                        1247064.73                     9232548.52
# 10   45.0                         518567.58                    14321565.18
# 11   13.0                          15488.55                        7518.77
# 12   50.0                           6784.92                        6143.50
# 13  157.0                          63152.26                      935134.49
# 14  115.0                          23055.64                       13724.96
# 15   58.0                           3780.36                        3817.78
# 16   26.0                           3107.42                        4887.37
# 17   24.0                           8190.89                       68413.44
# 18   20.0                          43767.95                       71390.80
# 19   59.0                          58015.64                       88631.90
# 20   60.0                          29123.06                       63027.57
# 21   84.0                          98121.54                       72352.47
# 22  205.0                         118799.27                      129159.89
# 23  105.0                          79534.59                      212445.88
# 24    8.0                           5258.34                        5188.87
# 25   71.0                        1183200.36                    12455434.53
# 26   49.0                          41261.22                       42673.97
# 27   33.0                         341517.58                        4950.25
# 28   34.0                         583310.58                         939.85
# 29   44.0                         544599.19                     2885016.06
# 30   51.0                           7838.24                     6920666.14
# 31   45.0                          14741.33                        9364.70
# 32  208.0                        2033529.73                     6376824.80
# 33  161.0                         903892.92                     6943748.84
# 34    9.0                           5688.77                            NaN
# 35  143.0                           3395.64                    18272288.93
# 36   14.0                         341505.24                        2937.63
# 37  228.0                         998172.50                      659065.27
# 38  178.0                           3236.99                     2685440.45
# 39   14.0                           7558.60                        1613.00
# 40   36.0                            586.00                        6346.93
# 41   14.0                          12988.82                          97.60
# 42   52.0                        1143881.77                         112.10
# 43  189.0                          29194.74                    18985409.81
# 44   22.0                        1152090.46                       28681.77
# 45   44.0                         195436.87                      248184.49
# 46  124.0                         105473.36                    12809681.79
# 47  305.0                        1130525.73                      128996.61
# 48   12.0                           3852.33                         569.55
# 49  121.0                           2582.42                    10240080.70
# 50   23.0                           3852.33                        1649.54
#
#     Barrels & Kegs (in Barrels) 2011  Btls & Cans (in Barrels) 2011  \
# 0                            1810.06                         658.96
# 1                           58519.66                       94781.57
# 2                           32848.92                       14057.56
# 3                            1144.17                        1382.06
# 4                         2166028.35                    18204514.85
# 5                         2277201.65                    18820319.55
# 6                            8033.77                        5578.56
# 7                           57886.92                      109745.27
# 8                            1366.16                         332.23
# 9                         1287687.46                     9380672.31
# 10                         482677.65                    14700163.67
# 11                          19606.37                       12683.85
# 12                           7749.54                        6407.47
# 13                          64148.06                      911312.40
# 14                          36461.47                       19393.24
# 15                           6320.58                        4178.10
# 16                           5670.63                        9179.79
# 17                           9276.72                       58747.18
# 18                          53422.01                       81163.65
# 19                          77600.43                      114906.50
# 20                          38254.66                       74120.55
# 21                         119862.81                       91092.86
# 22                         148703.06                      198151.04
# 23                         101033.14                      259668.58
# 24                           6867.94                        6646.41
# 25                        1119507.94                    12278066.32
# 26                          46957.49                       50457.49
# 27                         364000.89                        5885.50
# 28                         604493.47                        1790.02
# 29                         559276.11                     2734941.12
# 30                          10594.14                     5908969.19
# 31                           7871.97                       14169.83
# 32                        1886886.80                     5779655.18
# 33                        1010647.87                     6600785.11
# 34                           7000.95                            NaN
# 35                           4025.32                    18312552.08
# 36                         357252.69                        3593.60
# 37                        1081543.30                      772698.31
# 38                           3371.00                     3128166.80
# 39                          11769.84                        1692.00
# 40                           1237.88                       10771.16
# 41                          17597.04                         424.14
# 42                        1152638.24                        1051.89
# 43                          34548.18                    18934858.19
# 44                        1165692.37                       40477.43
# 45                         218671.75                      289840.71
# 46                          91368.48                    12531661.75
# 47                         981225.81                      121471.16
# 48                           5055.71                         120.33
# 49                           3264.98                     9002320.57
# 50                           5055.71                        1916.37
#
#     Barrels & Kegs (in Barrels) 2012  Btls & Cans (in Barrels) 2012  \
# 0                            6453.45                        2485.79
# 1                           65679.13                      105416.32
# 2                           44792.72                       18411.25
# 3                             125.94                           8.00
# 4                         2272663.96                    18940276.02
# 5                         2290799.82                    19267902.29
# 6                            6849.69                        6372.31
# 7                           65524.44                      129493.68
# 8                            4257.53                        1727.77
# 9                         1289450.36                     9738023.02
# 10                         480930.15                    15000803.63
# 11                          19391.33                       13350.64
# 12                          11316.83                        9112.66
# 13                          60573.70                      786867.40
# 14                          48867.09                       32664.02
# 15                           8572.43                        4309.38
# 16                           4768.33                        9537.42
# 17                          11795.65                       70540.28
# 18                          56196.18                       98359.97
# 19                          97285.94                      124123.97
# 20                          46213.33                       75360.92
# 21                         131474.98                      107665.45
# 22                         185386.44                      284832.91
# 23                         115956.35                      232657.19
# 24                           6481.96                        8051.63
# 25                        1019244.02                    12808818.03
# 26                          50172.95                       52892.54
# 27                           7244.52                        6780.45
# 28                           4993.73                        3647.33
# 29                         365463.83                     2927305.84
# 30                         502680.99                     4572952.86
# 31                          12803.35                       17164.28
# 32                         668632.48                     6830823.99
# 33                        1054976.57                     6735801.22
# 34                              0.00                            NaN
# 35                        1790342.28                    17318045.77
# 36                           4826.95                        3706.66
# 37                         372970.41                      847409.27
# 38                        1168462.04                     3411033.49
# 39                           4104.34                        2021.32
# 40                          15831.87                       12903.66
# 41                           1521.50                         619.70
# 42                          28387.58                      380277.00
# 43                        1144585.80                    17941441.31
# 44                          43143.32                       62120.44
# 45                          98154.92                      273965.87
# 46                        1175467.01                    13408374.35
# 47                         240103.86                      116944.26
# 48                           3701.81                          23.18
# 49                        1038914.37                     8884190.43
# 50                           5752.17                        2580.15
#
#     Barrels & Kegs (in Barrels) 2013  Btls & Cans (in Barrels) 2013  \
# 0                           11747.74                        6634.43
# 1                           68867.58                      112008.59
# 2                           59074.04                       22318.65
# 3                            1078.21                           8.00
# 4                         2383322.71                    17835501.70
# 5                         2177094.68                    18549122.13
# 6                           20486.04                       21549.90
# 7                           75629.27                      148156.85
# 8                            5934.43                        3546.13
# 9                         1260334.83                     9521482.11
# 10                         545302.04                    14681673.20
# 11                          18107.58                       13208.44
# 12                          15294.81                       11093.10
# 13                          68420.11                      944038.45
# 14                          61510.42                       37750.09
# 15                          13243.72                        5519.98
# 16                           6125.65                       11226.90
# 17                          19416.85                       78440.18
# 18                          62679.68                      101715.41
# 19                         110683.11                      122877.92
# 20                          52907.04                       89731.45
# 21                         126519.70                      127180.29
# 22                         227414.70                      272746.16
# 23                         133102.69                      253317.42
# 24                           6907.14                       10044.08
# 25                         942359.26                    12586027.39
# 26                          53795.28                       55867.96
# 27                           3840.44                        2073.18
# 28                           5702.72                        4561.27
# 29                         381402.55                     2854790.85
# 30                         443199.05                     4264380.69
# 31                          15093.44                       18327.17
# 32                         674239.50                     7166945.25
# 33                         988300.04                     6515751.81
# 34                            481.37                         133.11
# 35                        1726012.49                    16646929.63
# 36                           4840.77                        3141.24
# 37                         409397.18                      935395.50
# 38                        1172567.35                     4003618.11
# 39                           5174.14                        4181.58
# 40                          18103.48                       17725.52
# 41                           1753.50                         785.06
# 42                          31767.12                      560336.92
# 43                        1037500.19                    18372898.87
# 44                          45937.83                       80300.79
# 45                          98852.28                      271560.29
# 46                        1134449.57                    12891463.92
# 47                         274424.49                      125917.12
# 48                           4525.59                          87.86
# 49                        1071651.35                     9038409.69
# 50                           7216.88                        2755.25
#
#     Barrels & Kegs (in Barrels) 2014  Btls & Cans (in Barrels) 2014  \
# 0                           13749.96                        9521.26
# 1                           73823.62                      129181.74
# 2                           80134.06                       29645.05
# 3                            2787.48                         800.09
# 4                         2328511.86                    18052949.81
# 5                         2207491.04                    18035909.80
# 6                           33903.03                       50874.70
# 7                           82037.96                      167806.22
# 8                            8335.80                        4265.73
# 9                         1241152.79                     9438491.14
# 10                         489156.48                    13928837.73
# 11                          21582.44                       13039.35
# 12                          17477.57                       14718.98
# 13                         145366.05                      946824.69
# 14                          66607.28                       48204.65
# 15                          21012.89                        8090.96
# 16                           7418.78                       15852.43
# 17                          24062.82                       85461.15
# 18                          69442.53                      109386.36
# 19                         116007.36                      131706.80
# 20                          56886.90                      102880.25
# 21                         128549.48                      132815.26
# 22                         297520.14                      419973.01
# 23                         154949.51                      285724.01
# 24                           7726.08                       13409.98
# 25                         885636.40                    12357181.24
# 26                          58651.91                       64297.30
# 27                          13753.51                       12738.17
# 28                           8085.97                        6322.08
# 29                         367976.50                     2745595.26
# 30                         447843.58                     4316395.59
# 31                          21957.12                       26140.30
# 32                         595192.21                     6746563.90
# 33                         971611.89                     6311082.55
# 34                           2601.31                        1363.95
# 35                        1641541.04                    17042634.64
# 36                           6110.00                        5620.53
# 37                         473419.01                     1031603.39
# 38                        1244733.82                     4246684.37
# 39                           4551.43                        4949.18
# 40                          19762.34                       21211.65
# 41                           1923.75                         823.65
# 42                          60753.94                      696681.85
# 43                        1056367.60                    18837767.01
# 44                          51425.32                      101610.11
# 45                          93531.96                      258101.46
# 46                        1048495.09                    12259344.53
# 47                         296950.34                      140870.39
# 48                           5160.63                          43.45
# 49                        1066193.96                     9100215.78
# 50                           8379.14                        2447.42
#
#     Barrels & Kegs (in Barrels) 2015  Btls & Cans (in Barrels) 2015  \
# 0                           11465.23                       10543.00
# 1                           74606.28                      126309.22
# 2                           74997.94                       44081.10
# 3                            6965.83                         872.11
# 4                         2173320.10                    17670616.67
# 5                         2082879.02                    17755216.77
# 6                           38093.71                       79904.60
# 7                           83489.86                      176483.90
# 8                            8925.18                        9222.28
# 9                         1243754.48                     9841609.40
# 10                         462768.63                    12868266.98
# 11                          25424.30                       17643.83
# 12                          16864.87                       15257.78
# 13                         213970.33                     1177427.89
# 14                          64929.85                       55045.98
# 15                          15321.13                        6886.79
# 16                           8041.30                       19051.11
# 17                          30952.49                       99595.65
# 18                          71502.25                      109219.49
# 19                         117491.36                      136646.89
# 20                          64705.32                      113778.85
# 21                         148308.82                      139668.98
# 22                         329356.12                      541888.77
# 23                         153515.75                      314372.67
# 24                           5999.23                       11793.55
# 25                         881308.39                    12493739.84
# 26                          52552.65                       68278.32
# 27                          10422.01                       10792.33
# 28                           5036.97                        6010.43
# 29                         347827.51                     2856383.87
# 30                         422379.27                     3219516.57
# 31                          21869.66                       25974.86
# 32                         588031.67                     7218436.33
# 33                         951036.05                     6028220.92
# 34                           3456.60                        1891.37
# 35                        1616581.07                    18042852.11
# 36                           4539.32                        6990.95
# 37                         480637.45                     1082117.89
# 38                        1156459.72                     4141056.02
# 39                           3969.48                        5592.76
# 40                          19269.06                       24319.79
# 41                           2406.63                        1028.03
# 42                          87078.45                     1073651.26
# 43                        1026860.59                    18138800.58
# 44                          54961.49                      117512.50
# 45                          89387.18                      264417.40
# 46                        1017631.05                    11190922.96
# 47                         289198.47                      163285.81
# 48                           6640.44                          60.86
# 49                         936633.30                     9089798.44
# 50                           9357.70                        3409.94
#
#     2011 Rank  2011 Rate  2012 Rank  2012 Rate  2013 Rank  2013 Rate  \
# 0        40.0        9.6       32.0        8.0       29.0        7.2
# 1        19.0        7.6       20.0        7.1       26.0        6.9
# 2        38.0        9.5       35.0        8.3       35.0        7.7
# 3        26.0        8.3       28.0        7.6       30.0        7.3
# 4        50.0       11.7       49.0       10.4       48.0        8.9
# 5        29.0        8.4       31.0        7.9       25.0        6.8
# 6        31.0        8.8       35.0        8.3       38.0        7.8
# 7        17.0        7.5       23.0        7.2       19.0        6.7
# 8        44.0       10.2       41.0        9.0       45.0        8.5
# 9        42.0       10.0       38.0        8.5       30.0        7.3
# 10       44.0       10.2       45.0        9.2       43.0        8.2
# 11       13.0        6.8       12.0        6.0        8.0        4.9
# 12       26.0        8.3       23.0        7.2       15.0        6.2
# 13       41.0        9.7       41.0        9.0       49.0        9.1
# 14       34.0        9.1       35.0        8.3       35.0        7.7
# 15        5.0        5.5        5.0        5.1        6.0        4.7
# 16        9.0        6.5       11.0        5.7       11.0        5.3
# 17       37.0        9.4       34.0        8.2       42.0        8.1
# 18       20.0        7.8       20.0        7.1       19.0        6.7
# 19       23.0        7.9       26.0        7.5       17.0        6.6
# 20       15.0        7.2       17.0        7.0       17.0        6.6
# 21       16.0        7.3       15.0        6.7       19.0        6.7
# 22       47.0       10.4       44.0        9.1       47.0        8.8
# 23        9.0        6.5       10.0        5.6        8.0        4.9
# 24       42.0       10.0       41.0        9.0       46.0        8.6
# 25       30.0        8.5       17.0        7.0       19.0        6.7
# 26       14.0        6.9       12.0        6.0       13.0        5.4
# 27        2.0        4.4        2.0        4.0        2.0        3.8
# 28       51.0       13.0       51.0       11.2       51.0        9.6
# 29        4.0        5.4        9.0        5.5       10.0        5.1
# 30       35.0        9.3       47.0        9.3       43.0        8.2
# 31       17.0        7.5       20.0        7.1       27.0        7.0
# 32       26.0        8.3       38.0        8.5       35.0        7.7
# 33       46.0       10.3       47.0        9.3       40.0        7.9
# 34        1.0        3.5        1.0        3.1        1.0        2.9
# 35       31.0        8.8       25.0        7.4       33.0        7.5
# 36        8.0        5.9        6.0        5.3       11.0        5.3
# 37       38.0        9.5       40.0        8.8       40.0        7.9
# 38       23.0        7.9       29.0        7.8       32.0        7.4
# 39       49.0       11.0       49.0       10.4       50.0        9.3
# 40       48.0       10.6       45.0        9.2       34.0        7.6
# 41        3.0        4.7        3.0        4.3        2.0        3.8
# 42       33.0        9.0       29.0        7.8       38.0        7.8
# 43       20.0        7.8       15.0        6.7       15.0        6.2
# 44       12.0        6.7        8.0        5.4        5.0        4.6
# 45        5.0        5.5        4.0        5.0        4.0        4.4
# 46       11.0        6.6       12.0        6.0       14.0        5.7
# 47       35.0        9.3       33.0        8.1       27.0        7.0
# 48       25.0        8.1       26.0        7.5       19.0        6.7
# 49       20.0        7.8       17.0        7.0       19.0        6.7
# 50        7.0        5.8        6.0        5.3        6.0        4.7
#
#     2014 Rank  2014 Rate  2015 Rank  2015 Rate
# 0        40.0        6.8       42.0        6.1
# 1        43.0        6.9       46.0        6.5
# 2        40.0        6.8       42.0        6.1
# 3        26.0        6.1       26.0        5.2
# 4        47.0        7.5       44.0        6.2
# 5        15.0        5.0       10.0        3.9
# 6        36.0        6.6       32.0        5.6
# 7        20.0        5.7       21.0        4.9
# 8        50.0        7.8       51.0        6.9
# 9        29.0        6.3       29.0        5.4
# 10       44.0        7.1       38.0        5.9
# 11       10.0        4.4        6.0        3.6
# 12       14.0        4.8       11.0        4.1
# 13       44.0        7.1       38.0        5.9
# 14       24.0        5.9       20.0        4.8
# 15        7.0        4.2        7.0        3.7
# 16       12.0        4.6       13.0        4.2
# 17       34.0        6.5       29.0        5.4
# 18       32.0        6.4       45.0        6.3
# 19       19.0        5.6       16.0        4.4
# 20       22.0        5.8       26.0        5.2
# 21       20.0        5.7       23.0        5.0
# 22       46.0        7.3       29.0        5.4
# 23        7.0        4.2        7.0        3.7
# 24       48.0        7.6       46.0        6.5
# 25       28.0        6.2       23.0        5.0
# 26       13.0        4.7       11.0        4.1
# 27        2.0        3.3        2.0        3.0
# 28       51.0        7.9       49.0        6.7
# 29        9.0        4.3        4.0        3.4
# 30       38.0        6.7       32.0        5.6
# 31       38.0        6.7       48.0        6.6
# 32       29.0        6.3       28.0        5.3
# 33       29.0        6.3       34.0        5.7
# 34        1.0        2.7        1.0        2.7
# 35       22.0        5.8       21.0        4.9
# 36       11.0        4.5       13.0        4.2
# 37       40.0        6.8       34.0        5.7
# 38       24.0        5.9       25.0        5.1
# 39       49.0        7.7       40.0        6.0
# 40       32.0        6.4       40.0        6.0
# 41        3.0        3.4        3.0        3.1
# 42       34.0        6.5       37.0        5.8
# 43       16.0        5.1       18.0        4.5
# 44        4.0        3.8        5.0        3.5
# 45        5.0        4.0        7.0        3.7
# 46       17.0        5.2       16.0        4.4
# 47       26.0        6.1       34.0        5.7
# 48       36.0        6.6       49.0        6.7
# 49       18.0        5.4       19.0        4.6
# 50        6.0        4.1       13.0        4.2

# %%
master_df.dtypes[0:5]
# Out:
# State                    object
# Craft_Breweries         float64
# Breweries Per Capita    float64
# Econ. Impact            float64
# Econ.Impact/Capita      float64
# dtype: object

# %% [markdown]
# ## CRAFT BEER STATS BY STATE

# %% [markdown]
# In the sections below, some basic insights on the data gathered are displayed and visualized.

# %% [markdown]
# ### NUMBER CRAFT BREWERIES BY STATE

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9d242eee-201a-408a-bc1e-b2b2db031440">Loading BokehJS ...</span>
#     </div>

# %%
sort_df = master_df.ix[:, 0:2]
sort_df.sort_values(by='Craft_Breweries', ascending=False)[:10]
# Out:
#    State  Craft_Breweries
# 4     CA            518.0
# 47    WA            305.0
# 5     CO            284.0
# 37    OR            228.0
# 32    NY            208.0
# 22    MI            205.0
# 43    TX            189.0
# 38    PA            178.0
# 33    NC            161.0
# 13    IL            157.0

# %%
sort_df.sort_values(by='Craft_Breweries', ascending=False)[-10:]
# Out:
#    State  Craft_Breweries
# 18    LA             20.0
# 7     DE             15.0
# 36    OK             14.0
# 39    RI             14.0
# 41    SD             14.0
# 11    HI             13.0
# 48    WV             12.0
# 8     DC             10.0
# 34    ND              9.0
# 24    MS              8.0

# %% [markdown]
# Sorting the master DataFrame by different columns, we can get a quick look at states with the highest or lowest number of craft breweries by state. Not surprisingly, the states with the highest number of breweries also have the largest populations. Some states, like Colorado and Oregon, are not even in the top 20 states with regards to population, but have a large number of breweries.
#
# Near the bottom of the list, are mostly states with smaller populations, or are small in terms of square miles. Aside from population, many of these differences can be attributed to culture and state laws.

# %% [markdown]
# ### CRAFT BREWERIES PER CAPITA

# %%
sort_df = master_df.ix[:, 0:3]
sort_df.sort_values(by='Breweries Per Capita', ascending=False)[:10]
# Out:
#    State  Craft_Breweries  Breweries Per Capita
# 45    VT             44.0                   9.4
# 37    OR            228.0                   7.7
# 5     CO            284.0                   7.3
# 26    MT             49.0                   6.5
# 19    ME             59.0                   5.9
# 47    WA            305.0                   5.9
# 50    WY             23.0                   5.5
# 1     AK             27.0                   5.3
# 29    NH             44.0                   4.5
# 12    ID             50.0                   4.4

# %% [markdown]
# Looking at the quantity of craft beer breweries per capita, Vermont rises to the top, but only because of the extremely small population of the state (VT ranks 49 out of 50 states in terms of population). Again, we see some of the same states with large numbers of breweries regardless of population. Making a broad assumption, many of the states with high numbers of breweries per capita have a lot of outdoor culture (hiking, skiing, etc.), something you may want to keep in mind if opening your own brewery.

# %% [markdown]
# ### CRAFT BEER CONSUMPTION

# %%
# Top 10 States by Beer Consumption per Adult
sort_df = master_df[['State', 'Barrels', 'Gallons/Adult']]
top_gal = sort_df.sort_values(by='Gallons/Adult', ascending=False)[:10]

bar1 = Bar(top_gal, values='Gallons/Adult', label=['State'],
           title="TOP STATES, Gal. per Adult Produced", legend=False, color='#F0B27A', plot_width=800)

bar1.title.text_font_size = '16pt'


# Top 10 States by Barrels Produced
sort_df = master_df[['State', 'Barrels', 'Gallons/Adult']]
top_barrel = sort_df.sort_values(by='Barrels', ascending=False)[:10]

bar2 = Bar(top_barrel, values='Barrels', label=['State'],
           title="TOP STATES, Barrels Produced", legend=False, color='#D68910', plot_width=800)

bar2.title.text_font_size = '16pt'


show(gridplot([[bar1, bar2]], plot_width=450, plot_height=600))  # side-by-side bar charts
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="10ab7776-d49a-427c-b1a0-429d90d9cd6c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("10ab7776-d49a-427c-b1a0-429d90d9cd6c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '10ab7776-d49a-427c-b1a0-429d90d9cd6c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b621c8f-4c8b-4e99-ac54-810ed29ff165":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7bb7775-3151-4e84-bbdb-b58f9ac0f350","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["CO"],"chart_index":[{"State":"CO"}],"color":["#F0B27A"],"fill_alpha":[0.8],"height":[14.1],"label":[{"State":"CO"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["CO"],"y":[7.05]}},"id":"90878f9c-4659-4f5d-bf2a-9025a0267620","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["VT"],"chart_index":[{"State":"VT"}],"color":["#F0B27A"],"fill_alpha":[0.8],"height":[17.4],"label":[{"State":"VT"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["VT"],"y":[8.7]}},"id":"eed748a2-0f06-4274-a274-f4022c2acba2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2f8377c-58ff-482a-bc32-a247d4a895e0","type":"Rect"},{"attributes":{},"id":"8c16c8ac-d716-4e74-8e09-76e4eb4ab94f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"994c78aa-2637-4838-9561-4d4ef3704cfe","subtype":"Chart","type":"Plot"}},"id":"d067d664-30ad-49ef-8393-34816f596e2d","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["TX"],"chart_index":[{"State":"TX"}],"color":["#D68910"],"fill_alpha":[0.8],"height":[1135043.0],"label":[{"State":"TX"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["TX"],"y":[567521.5]}},"id":"07fb8ed2-0455-4906-8037-1475c70848e8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["OH"],"chart_index":[{"State":"OH"}],"color":["#D68910"],"fill_alpha":[0.8],"height":[1385100.0],"label":[{"State":"OH"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["OH"],"y":[692550.0]}},"id":"24082475-0f44-485d-bb65-a47d1c5fec4c","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"994c78aa-2637-4838-9561-4d4ef3704cfe","subtype":"Chart","type":"Plot"},"ticker":{"id":"165fffa5-8567-41d0-954f-825f9788e857","type":"BasicTicker"}},"id":"38fb429d-92a7-4f28-8f1b-ee0a9db57f60","type":"Grid"},{"attributes":{"plot":{"id":"994c78aa-2637-4838-9561-4d4ef3704cfe","subtype":"Chart","type":"Plot"}},"id":"452eeb9e-f5bd-4e55-8f63-094177dd62a4","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ecf29b7-5156-403e-a488-cbc99a6354b0","type":"Rect"},{"attributes":{"callback":null,"end":18.27},"id":"5bf44179-8244-48f7-942a-d7c00d6cf40b","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ac4a934-34fc-42dc-b8e0-052fc1533ef1","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[29]</strong>&gt;</code></p>

# %% [markdown]
# The number of breweries doesn't tell the whole story. A state may have a large number of breweries, but some states are home to breweries with larger distribution networks, or higher production amounts.
#
# Examining the states with the most gallons per adult, we see a lot of the smaller states with higher numbers of breweries per capita. When looking at the top states for production, there are many higher population states, but these states are also home to some of the largest craft breweries (D. G. Yuengling in PA, Sierra Nevada and Lagunitas in CA, New Belgium Brewing in CO, etc.)

# %% [markdown]
# ### TOP TEN STATES, OVERALL BEER PRODUCTION
#
# Below are the top ten states for overall beer production in the U.S., not just for craft beer and breweries, as all of the other tables have demonstrated.
#
# The totals below (for 2010 and 2015) are for totals of Barrels, Kegs, Bottles & Cans, so most of the ways in which beer is distributed is captured. The states listed are home to the larger "craft" breweries (Massachusetts, home to Sam Adams, finally makes an appearance), but many of the larger beer companies (SAB Miller, InBev, etc.) don't just exclusively make beer in the states they are known for (Missouri, Colorado), and those states make an appearance in the top 10 largest beer producing states in 2015.

# %%
sort_df = master_df

sort_df['2015 Total'] = sort_df['Barrels & Kegs (in Barrels) 2015'] + sort_df['Btls & Cans (in Barrels) 2015']

sort_df[['State', 'Barrels & Kegs (in Barrels) 2015', 
         'Btls & Cans (in Barrels) 2015', '2015 Total']].sort_values(by='2015 Total', ascending=False)[:10]
# Out:
#    State  Barrels & Kegs (in Barrels) 2015  Btls & Cans (in Barrels) 2015  \
# 4     CA                        2173320.10                    17670616.67
# 5     CO                        2082879.02                    17755216.77
# 35    OH                        1616581.07                    18042852.11
# 43    TX                        1026860.59                    18138800.58
# 25    MO                         881308.39                    12493739.84
# 10    GA                         462768.63                    12868266.98
# 46    VA                        1017631.05                    11190922.96
# 9     FL                        1243754.48                     9841609.40
# 49    WI                         936633.30                     9089798.44
# 32    NY                         588031.67                     7218436.33
#
#      2015 Total
# 4   19843936.77
# 5   19838095.79
# 35  19659433.18
# 43  19165661.17
# 25  13375048.23
# 10  13331035.61
# 46  12208554.01
# 9   11085363.88
# 49  10026431.74
# 32   7806468.00

# %% [markdown]
# Despite large states with many breweries and large beer producting corporations listed above, the states with the largest volume change in production from 2010 to 2015 are listed below. We see states that have been mentioned previously when talking about craft beer production (PA, OH, MI, etc.), but these states are home to some larger craft brewers, as well as some of the "craft" brands owned by the larger mass-production breweries (like Blue Moon by Miller Coors, and Shock Top by Anheuser-Busch).

# %%
sort_df = master_df

sort_df['2010 Total'] = sort_df['Barrels & Kegs (in Barrels) 2010'] + sort_df['Btls & Cans (in Barrels) 2010']
sort_df['2015 Total'] = sort_df['Barrels & Kegs (in Barrels) 2015'] + sort_df['Btls & Cans (in Barrels) 2015']
sort_df['5-Year Production Change'] = sort_df['2015 Total'] - sort_df['2010 Total']

prod_change = sort_df[['State', '2010 Total', '2015 Total',
                       '5-Year Production Change']].sort_values(by='5-Year Production Change', ascending=False)[:10]

prod_change
# Out:
#    State   2010 Total   2015 Total  5-Year Production Change
# 38    PA   2688677.44   5297515.74                2608838.30
# 35    OH  18275684.57  19659433.18                1383748.61
# 22    MI    247959.16    871244.89                 623285.73
# 9     FL  10479613.25  11085363.88                 605750.63
# 13    IL    998286.75   1391398.22                 393111.47
# 23    MN    291980.47    467888.42                 175907.95
# 43    TX  19014604.55  19165661.17                 151056.62
# 7     DE    137870.81    259973.76                 122102.95
# 21    MA    170474.01    287977.80                 117503.79
# 19    ME    146647.54    254138.25                 107490.71

# %% [markdown]
# ### CRAFT BEER AS A PERCENT OF OVERALL PRODUCTION

# %% [markdown]
# In the table created below, craft beer is a large share of overall production in five states (35%+), and then quickly drops off from there to more modest shares of overall beer production.
#
# New Jersey is home to many craft breweries, but also one plant for Anheuser-Busch in Newark, which producers Budweiser and Rolling Rock in the state. Since this is the only large brewer, but it is a state with a high and dense population, and the demographics and economy support a significant number of craft breweries.
#
# A similar story exists in the other states listed - large numbers of craft beer breweries, with an existing "non-craft" production facility located somewhere in the state.

# %%
sort_df = master_df

sort_df['2015 Total'] = sort_df['Barrels & Kegs (in Barrels) 2015'] + sort_df['Btls & Cans (in Barrels) 2015']
sort_df['Craft % of Total Beer Prod.'] = sort_df['2015 Total'] / sort_df['Barrels']

craft_pct = sort_df[['State', 'Barrels & Kegs (in Barrels) 2015', 
                     'Btls & Cans (in Barrels) 2015', '2015 Total', 
                     'Barrels', 'Craft % of Total Beer Prod.']].sort_values(by='Craft % of Total Beer Prod.', ascending=False)[:10]

craft_pct
# Out:
#    State  Barrels & Kegs (in Barrels) 2015  Btls & Cans (in Barrels) 2015  \
# 30    NJ                         422379.27                     3219516.57
# 46    VA                        1017631.05                    11190922.96
# 25    MO                         881308.39                    12493739.84
# 10    GA                         462768.63                    12868266.98
# 29    NH                         347827.51                     2856383.87
# 43    TX                        1026860.59                    18138800.58
# 35    OH                        1616581.07                    18042852.11
# 5     CO                        2082879.02                    17755216.77
# 33    NC                         951036.05                     6028220.92
# 49    WI                         936633.30                     9089798.44
#
#      2015 Total    Barrels  Craft % of Total Beer Prod.
# 30   3641895.84    79942.0                    45.556727
# 46  12208554.01   274111.0                    44.538723
# 25  13375048.23   359864.0                    37.166953
# 10  13331035.61   365015.0                    36.521884
# 29   3204211.38    94094.0                    34.053302
# 43  19165661.17  1135043.0                    16.885405
# 35  19659433.18  1385100.0                    14.193512
# 5   19838095.79  1775831.0                    11.171162
# 33   6979256.97   675469.0                    10.332461
# 49  10026431.74  1020567.0                     9.824374

# %% [markdown]
# ### GROWTH IN CRAFT BREWERIES

# %%
sort_df = master_df
sort_df['% Change No. Breweries'] = ((sort_df['2015'] - sort_df['2011']) / sort_df['2011']) * 100
pct_change = sort_df[['State', '% Change No. Breweries']].sort_values(by='% Change No. Breweries', ascending=False)[:15]
pct_change
# Out:
#    State  % Change No. Breweries
# 34    ND              350.000000
# 3     AR              333.333333
# 0     AL              300.000000
# 24    MS              300.000000
# 9     FL              235.555556
# 43    TX              220.338983
# 35    OH              217.777778
# 46    VA              210.000000
# 23    MN              200.000000
# 29    NH              193.333333
# 13    IL              190.740741
# 41    SD              180.000000
# 32    NY              177.333333
# 33    NC              172.881356
# 18    LA              150.000000

# %% [markdown]
# Creating a calculated column in the DataFrame, we can look at the amount of change in the number of Craft Breweries between the years of 2011 and 2015. To note, the amounts above are percentages! One could conclude that these huge percentage changes are simply due to a state with a small number of breweries adding a few more, but the top third of the list contains states with large numbers already (FL, TX, OH, NY). In fact, the lowest % growth in the number of breweries is still a 1/3 increase in the number of craft breweries. Further more, 30 out of 50 states have doubled the number of craft breweries of more.

# %%
# bar chart using Bokeh
bar3 = Bar(pct_change, values='% Change No. Breweries', label=['State'],
           title="Top States, % Change No. Breweries", legend=False, color='navy', plot_width=800)

bar3.title.text_font_size = '16pt'

show(row(bar3))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="33a9e363-3579-4ed5-8998-b403b822e7b5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("33a9e363-3579-4ed5-8998-b403b822e7b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '33a9e363-3579-4ed5-8998-b403b822e7b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a0f989fe-9d32-4b6a-a3d1-dfe0928e483a":{"roots":{"references":[{"attributes":{"plot":{"id":"30cb5b89-690d-4fba-91d1-e5046fe04165","subtype":"Chart","type":"Plot"}},"id":"059040e9-ef07-4933-9b29-c44eed063e2d","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["ND"],"chart_index":[{"State":"ND"}],"color":["navy"],"fill_alpha":[0.8],"height":[350.0],"label":[{"State":"ND"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["ND"],"y":[175.0]}},"id":"8d86e8e9-af76-41d7-ada9-1af09e4ca66e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"30cb5b89-690d-4fba-91d1-e5046fe04165","subtype":"Chart","type":"Plot"}},"id":"96fd4ed9-8269-4290-908b-6d4beb036a2b","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"96fd4ed9-8269-4290-908b-6d4beb036a2b","type":"PanTool"},{"id":"85ba6852-859e-45bb-a715-60490f77acdd","type":"WheelZoomTool"},{"id":"c2ae4090-210d-4988-94c9-e91233f0b7bf","type":"BoxZoomTool"},{"id":"059040e9-ef07-4933-9b29-c44eed063e2d","type":"SaveTool"},{"id":"f84f407a-6629-4e55-8d48-b8a5644aa98a","type":"ResetTool"},{"id":"b873b196-bb85-4d68-90b6-220713427bf2","type":"HelpTool"}]},"id":"61482f15-a78c-48b0-b2f6-ee8ae63670e1","type":"Toolbar"},{"attributes":{"callback":null,"end":367.5},"id":"7fddce33-232f-4153-afef-f612596b2fc8","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"76c688c2-f158-41f4-95fb-0f215d6cba55","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"30cb5b89-690d-4fba-91d1-e5046fe04165","subtype":"Chart","type":"Plot"},"ticker":{"id":"f832c31f-d86f-49e3-b16c-15692bd47ce2","type":"BasicTicker"}},"id":"e290c508-4c1e-4acf-97ba-334a2f59a48e","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f59a6bc4-6aee-431b-984d-9a435fa08878","type":"Rect"},{"attributes":{"plot":null,"text":"Top States, % Change No. Breweries","text_font_size":{"value":"16pt"}},"id":"24f7ef72-f871-4e4c-93d1-e44d234ae1c4","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7cb77c0-541d-46a8-bc27-cf6d67c8c219","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2930ba35-542a-4775-92cb-af13a63d6477","type":"Rect"},{"attributes":{"data_source":{"id":"9a9e3d15-e43d-451f-ba70-48f463d71111","type":"ColumnDataSource"},"glyph":{"id":"2930ba35-542a-4775-92cb-af13a63d6477","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1f962df5-00af-4e4a-ae92-9bdf16f8fbb3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fdf1b9ba-d8de-42a5-ba24-f963abc3a6b0","type":"Rect"},{"attributes":{"data_source":{"id":"4e2cd285-6f2e-48e2-b38c-ec1e9ab6b328","type":"ColumnDataSource"},"glyph":{"id":"50eb337b-9ca7-4188-83e0-cc46c829dbf2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"sel ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[34]</strong>&gt;</code></p>

# %% [markdown]
# ### UNEMPLOYMENT RATE
# Using the same methodology as comparing the percent growth in the number of breweries, we can look at the unemployment rate change of each state.

# %%
sort_df = master_df
sort_df['% Change Unemp. Rate'] = ((sort_df['2015 Rate'] - sort_df['2011 Rate']) / sort_df['2011 Rate']) * 100
unemp_change = sort_df[['State', '% Change Unemp. Rate']].sort_values(by='% Change Unemp. Rate', ascending=False)

bar4 = Bar(unemp_change, values='% Change Unemp. Rate', label=['State'],
           title="% Change in Unemployment Rate", legend=False, color='#E74C3C', plot_width=900)

bar4.title.text_font_size = '16pt'

show(row(bar4))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e8c8b7c7-f701-4624-be03-40c297ebd0c9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e8c8b7c7-f701-4624-be03-40c297ebd0c9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e8c8b7c7-f701-4624-be03-40c297ebd0c9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c888bea5-679c-4ff2-ade4-eed196ec05d6":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["PA"],"chart_index":[{"State":"PA"}],"color":["#E74C3C"],"fill_alpha":[0.8],"height":[-35.44303797468355],"label":[{"State":"PA"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["PA"],"y":[-17.721518987341774]}},"id":"7e7d954d-4ad5-47a0-98a3-1f7fcfa8ff99","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fbbed191-1f74-4d55-8fa4-5f0c9113b0f9","type":"ColumnDataSource"},"glyph":{"id":"db5b5089-12a5-43fc-991b-9d5dc32eee2b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"66403e81-60c6-42ba-aed1-047ec35c5669","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["OK"],"chart_index":[{"State":"OK"}],"color":["#E74C3C"],"fill_alpha":[0.8],"height":[-28.8135593220339],"label":[{"State":"OK"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["OK"],"y":[-14.40677966101695]}},"id":"9be2ddab-21f0-4787-9a05-77ab63631266","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["TX"],"chart_index":[{"State":"TX"}],"color":["#E74C3C"],"fill_alpha":[0.8],"height":[-42.30769230769231],"label":[{"State":"TX"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["TX"],"y":[-21.153846153846153]}},"id":"f7c0196d-350a-454b-8759-d0a6f324f67f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f8fc7b1a-4e72-4dce-bb1b-92821c34f51f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bf7baa44-9e1b-47db-a214-0c1ffea1a806","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["OH"],"chart_index":[{"State":"OH"}],"color":["#E74C3C"],"fill_alpha":[0.8],"height":[-44.31818181818182],"label":[{"State":"OH"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["OH"],"y":[-22.15909090909091]}},"id":"149d8cf8-02f4-471b-8235-c575f45c7087","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"673049d4-b77d-4ec7-a52d-e74334f0b874","subtype":"Chart","type":"Plot"}},"id":"f74aad9a-a182-4a33-b8ff-586da2b727dc","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"929810b0-b674-4066-9376-455f3496d6d4","type":"PanTool"},{"id":"2b4606e0-c7a5-4ab4-85b4-25928c5544c1","type":"WheelZoomTool"},{"id":"58ec973e-7d52-4ee4-95fc-57fc48f03373","type":"BoxZoomTool"},{"id":"ba25b934-d0de-4dff-8021-3c14f638e244","type":"SaveTool"},{"id":"d5eb1665-62bf-4d19-9853-b588317bb961","type":"ResetTool"},{"id":"f74aad9a-a182-4a33-b8ff-586da2b727dc","type":"HelpTool"}]},"id":"e84a9190-7925-47d3-9fa0-5f5d970b9a17","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"State":["LA"],"chart_index":[{"State":"LA"}],"color":["#E74C3C"],"fill_alpha":[0.8],"height":[-19.230769230769234],"label":[{"State":"LA"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["LA"],"y":[-9.615384615384617]}},"id":"8492bc73-f70d-4965-b11c-a84d67755718","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c1d138b6-f307-45f5-9965-a8aeb69f4339","type":"ColumnDat ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[35]</strong>&gt;</code></p>

# %% [markdown]
# The chart above shows the decrease in the unemployment rate for each state from 2011 to 2015. Not surprisingly, every state has seen a decrease in state-wide unemployment. Some of the states with high growth in craft breweries also appear here for larger decreases in state unemployment rate.
#
# The drop in unemployment rate is certainly not solely caused by everyone working at a craft brewery, but the craft brewery movement may have been driven by those out of work, with no other options. This may have perfectly coincided with a perfect storm of 18-35 year-olds preferring to spend money on experiences and technology allowing for easier access to smaller businesses. Many people after losing their source of income in 2008-2009, looked to use other talents or hobbies to make ends meet.
#
# It should be noted that many of the states with larger drops in unemployment also have other major industries, with the explosion in tech providing jobs in states like California, Colorado, Ohio, and New York.

# %%
beer_cor = unemp_change.merge(pct_change, on='State')
beer_cor

scatter = Scatter(beer_cor, x='% Change Unemp. Rate', y='% Change No. Breweries', color='#1ABC9C', 
                  title="Change in Unemp. Rate vs. Craft Beer Growth (Top 15 States)", marker='State', 
                  legend="top_left", plot_height=650, plot_width=800)

scatter.title.text_font_size = '16pt'

scatter.legend.orientation = 'horizontal'

show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5ad9184c-a4d7-4375-958f-1558b56b752f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ad9184c-a4d7-4375-958f-1558b56b752f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ad9184c-a4d7-4375-958f-1558b56b752f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"212e8d8e-8998-46b1-bc2a-dd1eda6e98f3":{"roots":{"references":[{"attributes":{"plot":{"id":"5ad2f974-560a-4a4a-b859-a1e3926c88b4","subtype":"Chart","type":"Plot"}},"id":"94fa03c4-f8e3-4ac2-b6e1-cab0f00f0a54","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#1ABC9C"},"line_color":{"value":"#1ABC9C"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"81794f82-af67-41eb-938a-1b068433733d","type":"Triangle"},{"attributes":{"axis_label":"% Change Unemp. Rate","formatter":{"id":"a1ee4f61-995e-4225-bc9f-1d13a76d6455","type":"BasicTickFormatter"},"plot":{"id":"5ad2f974-560a-4a4a-b859-a1e3926c88b4","subtype":"Chart","type":"Plot"},"ticker":{"id":"29a33c02-c32e-4cfb-a084-ba9e07fd3ede","type":"BasicTicker"}},"id":"5a802c9d-b652-4638-9826-a15f1530a349","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"State":["NH"],"chart_index":[{"State":"NH"}],"x_values":[-37.03703703703704],"y_values":[193.33333333333334]}},"id":"b4484839-d501-43fa-a3c6-d752814f7570","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"State":["MN"],"chart_index":[{"State":"MN"}],"x_values":[-43.07692307692307],"y_values":[200.0]}},"id":"fa838047-b2d4-4828-b319-9ae18bdae68d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#1ABC9C"},"line_color":{"value":"#1ABC9C"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c96b3765-bff7-409f-80eb-b571a301cd99","type":"CircleX"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"State":["AR"],"chart_index":[{"State":"AR"}],"x_values":[-37.34939759036145],"y_values":[333.33333333333337]}},"id":"e7e796a7-51df-44e7-9087-1570303531ff","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fa838047-b2d4-4828-b319-9ae18bdae68d","type":"ColumnDataSource"},"glyph":{"id":"1dcc9740-362c-4353-b4e4-1aace09ea544","type":"Asterisk"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2ec85a04-e82d-42fb-a5ec-86e2d78272ae","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"20100fa0-9058-4412-9d25-16ef5f498c57","type":"ColumnDataSource"},"glyph":{"id":"fd860b93-9632-4d65-bc8e-0a89aacd2e23","type":"Square"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ece656f6-1c4d-4cba-8ff4-832998534774","type":"GlyphRenderer"},{"attributes":{"axis_label":"% Change No. Breweries","formatter":{"id":"53f22ae9-b522-4822-b8ae-ceb6506d42c4","type":"BasicTickFormatter"},"plot":{"id":"5ad2f974-560a-4a4a-b859-a1e3926c88b4","subtype":"Chart","type":"Plot"},"ticker":{"id":"2b76daea-f530-41d6-ba86-93e4b9b0aa34","type":"BasicTicker"}},"id":"0d9dd562-151a-4692-8b9a-f9e500efb650","type":"LinearAxis"},{"attributes":{"data_source":{"id":"eece77d0-42d5-4703-94b7-deac325a7803","type":"ColumnDataSource"},"glyph":{"id":"81794f82-af67-41eb-938a-1b068433733d","type":"Triangle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c0497480-6079-4721-a1d5-be44de4812ee","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"State":["MS"],"chart_index":[{"State":"MS"}],"x_values":[-35.0],"y_values":[300.0]}},"id":"c0436956-4d96-4c77-b417-47ff90046a45","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b4484839-d501-43fa-a3c6-d752814f7570","type":"ColumnDataSource"},"glyph":{"id":"c96b3765-bff7-409f-80eb-b571a301cd99","type":"CircleX"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"31e4530d-e20c-4408-9b1f-2619a9f8d8c4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"625da876-ad34-403a-9648-627eaef7af41","type":"ColumnDataSource"},"glyph":{"id":"3258621d-cd2f-41a0-972a-a125752c7f87","type":"Diamond"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"93c3d14f-b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[36]</strong>&gt;</code></p>

# %% [markdown]
# The scatter plot shows a correlation between the growth in breweries and the decline in unemployment rate. Other factors are obviously at play, but the relationship is certainly interesting.

# %% [markdown]
# ## CONCLUSION
#
# This project merely touches the surface of a very large and diverse industry. I wanted to pull together data from a variety of sources and make some broad conclusions from it. More research into production volume, the exact definitions of craft versus other brewers, and other data would need to be combined to make a more in-depth study.
#
# From most of the information I have gathered, it appears that the growth of craft brewing is driven by societal changes (looking at the ratio or migration of age groups into certain states would be interesting), economic factors, and the spread of information (it's easier than ever to learn how to do almost anything because of the wealth of information available on-line).
#
# Mainly I have learned that beer is made and consumed in huge quantities, and that every state has some sort of beer production, with others leading the way over other states due to population size, culture, and laws on alcohol production.
